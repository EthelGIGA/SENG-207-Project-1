# %% [markdown]
# # <p >Ethel Enam Abla Nyamador </p>
# # <p>ID : 10947078 </p>
# # <p>Department: BMEN</p>
# # <p >SENG 207 PROGRAMMING FOR ENGINEERS PROJECT 1</p>

# %% [markdown]
# # DATA ANALYSIS
# ---

# %% [markdown]
# ## IMPORTING LIBRARIES

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
dataset_1 = pd.read_csv('data.csv')

# %%
dataset_1
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# ## Info about columns

# %%
dataset_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %% [markdown]
# ## Counting Null Values

# %%
dataset_1.isna().sum()
# Out:
# ID                      0
# fixed acidity           1
# volatile acidity        0
# citric acid             1
# residual sugar          0
# chlorides               3
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %% [markdown]
# ### *Filling null values with Median method*

# %%
data_mode= dataset_1.median()
dataset_2 = dataset_1.fillna(data_mode)
dataset_2
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
dataset_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1601 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1601 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1601 non-null   float64
#  6   free sulfur dioxide   1601 non-null   float64
#  7   total sulfur dioxide  1601 non-null   float64
#  8   density               1601 non-null   float64
#  9   pH                    1601 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1601 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %% [markdown]
# ## Checking for duplicates

# %%
dataset_2.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1596    False
# 1597    False
# 1598    False
# 1599    False
# 1600    False
# Length: 1601, dtype: bool

# %%
dataset_2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## DATA INFERENCE
# ---

# %% [markdown]
# ### DATA CORRELATION BETWEEN TWO COLUMNS

# %%
dataset_2.iloc[:, 1:].corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255613     0.670988
# volatile acidity          -0.255613          1.000000    -0.552901
# citric acid                0.670988         -0.552901     1.000000
# residual sugar             0.114651          0.001877     0.143523
# chlorides                  0.093664          0.061101     0.203800
# free sulfur dioxide       -0.153191         -0.010643    -0.061151
# total sulfur dioxide      -0.113159          0.076198     0.036150
# density                    0.667828          0.022755     0.364100
# pH                        -0.682574          0.235176    -0.542599
# sulphates                  0.182357         -0.261364     0.312866
# alcohol                   -0.061868         -0.202672     0.109960
# quality                    0.125355         -0.390806     0.227102
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# ### OTHER DATA INFERENCES

# %%
dataset_2.iloc[:, 1:].describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1601.000000       1601.000000  1601.000000     1601.000000
# mean        8.319613          0.527742     0.271168        2.538445
# std         1.739527          0.178981     0.194684        1.409138
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1601.000000          1601.000000           1601.000000  1601.000000
# mean      0.087472            15.885696             46.514678     0.996746
# std       0.047033            10.455324             32.968104     0.001887
# ...

# %% [markdown]
# ### FINDING MODE AND MEDIAN FOR EACH COLUMN

# %%
mode_dataset_2 = dataset_2.iloc[:, 1:].mode().iloc[0]
median_dataset_2 = dataset_2.iloc[:, 1:].median()

# %%
print("Mode:")
print(mode_dataset_2)
# Out:
# Mode:
# fixed acidity            7.2000
# volatile acidity         0.6000
# citric acid              0.0000
# residual sugar           2.0000
# chlorides                0.0800
# free sulfur dioxide      6.0000
# total sulfur dioxide    28.0000
# density                  0.9972
# pH                       3.3000
# sulphates                0.6000
# alcohol                  9.5000
# quality                  5.0000
# Name: 0, dtype: float64

# %%
print("Median:")
print(mode_dataset_2)
# Out:
# Median:
# fixed acidity            7.2000
# volatile acidity         0.6000
# citric acid              0.0000
# residual sugar           2.0000
# chlorides                0.0800
# free sulfur dioxide      6.0000
# total sulfur dioxide    28.0000
# density                  0.9972
# pH                       3.3000
# sulphates                0.6000
# alcohol                  9.5000
# quality                  5.0000
# Name: 0, dtype: float64

# %% [markdown]
# ### *DATA VISUALIZATION*

# %% [markdown]
# ### Data Visualization for 'Fixed Acidity'

# %%
dat_mean = dataset_2['fixed acidity'].mean()

# Count values Greater than or Leass than Mean
above_mean_count = dataset_2[dataset_2['fixed acidity'] > dat_mean]['fixed acidity'].count()
below_mean_count = dataset_2[dataset_2['fixed acidity'] < dat_mean]['fixed acidity'].count()

# Create pie chart
labels = ['Greater than mean', 'Less than mean']
sizes = [above_mean_count, below_mean_count]
colors = ['#5751E3', '#D30F77']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Fixed Acidity Greater than or Leass than Mean')
plt.show()

# %%
plot1 = sns.histplot(data=dataset_2, x='fixed acidity',color='#70E9FF')

plot1.set_title("Fixed Acidity Histogram") #title
# Out:
# Text(0.5, 1.0, 'Fixed Acidity Histogram')

# %% [markdown]
# ####  _inference above and below the mean can provide important insights into the distribution and patterns in the data, as well as allow for meaningful comparisons between groups_

# %% [markdown]
# ### Data Visualization for 'Volatile Acidity'

# %%
plot1 = sns.histplot(data=dataset_2, x='volatile acidity',color='#70E9FF')

plot1.set_title("Volatile Acidity Histogram") #title
# Out:
# Text(0.5, 1.0, 'Volatile Acidity Histogram')

# %%
dat_mean = dataset_2['volatile acidity'].mean()

# Count values Greater than or Leass than Mean
above_mean_count = dataset_2[dataset_2['volatile acidity'] > dat_mean]['volatile acidity'].count()
below_mean_count = dataset_2[dataset_2['volatile acidity'] < dat_mean]['volatile acidity'].count()

# Create pie chart
labels = ['Greater than mean', 'Less than mean']
sizes = [above_mean_count, below_mean_count]
colors = ['#92D30F','blue']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Volatile Acidity Greater than or Leass than Mean')
plt.show()

# %% [markdown]
# ### Data Visualization for 'Citric Acid'

# %%
plot1 = sns.histplot(data=dataset_2, x='citric acid',color='#70E9FF')

plot1.set_title("Citric Acid Histogram") #title
# Out:
# Text(0.5, 1.0, 'Citric Acid Histogram')

# %%
dat_mean = dataset_2['citric acid'].mean()

# Count values Greater than or Leass than Mean
above_mean_count = dataset_2[dataset_2['citric acid'] > dat_mean]['citric acid'].count()
below_mean_count = dataset_2[dataset_2['citric acid'] < dat_mean]['citric acid'].count()

# Create pie chart
labels = ['Greater than mean', 'Less than mean']
sizes = [above_mean_count, below_mean_count]
colors = ['#CAD30F','#70E9FF']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Citric Acid Greater than or Leass than Mean')
plt.show()

# %% [markdown]
# ### Data Visualization for 'Residual Sugar'

# %%
plot1 = sns.histplot(data=dataset_2, x='residual sugar',color='#70E9FF')

plot1.set_title("Residual Sugar Histogram") #title
# Out:
# Text(0.5, 1.0, 'Residual Sugar Histogram')

# %%
dat_mean = dataset_2['residual sugar'].mean()

# Count values Greater than or Leass than Mean
above_mean_count = dataset_2[dataset_2['residual sugar'] > dat_mean]['residual sugar'].count()
below_mean_count = dataset_2[dataset_2['residual sugar'] < dat_mean]['residual sugar'].count()

# Create pie chart
labels = ['Greater than mean', 'Less than mean']
sizes = [above_mean_count, below_mean_count]
colors = ['#D6E9FF', '#70E9FF']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Residual Sugar Greater than or Leass than Mean')
plt.show()

# %% [markdown]
# ### Data Visualization for 'Chlorides'

# %%
plot1 = sns.histplot(data=dataset_2, x='chlorides',color='#70E9FF')

plot1.set_title("Chlorides Histogram") #title
# Out:
# Text(0.5, 1.0, 'Chlorides Histogram')

# %%
dat_mean = dataset_2['chlorides'].mean()

# Count values Greater than or Leass than Mean
above_mean_count = dataset_2[dataset_2['chlorides'] > dat_mean]['chlorides'].count()
below_mean_count = dataset_2[dataset_2['chlorides'] < dat_mean]['chlorides'].count()

# Create pie chart
labels = ['Greater than mean', 'Less than mean']
sizes = [above_mean_count, below_mean_count]
colors = ['pink', 'red']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Chlorides Greater than or Leass than Mean')
plt.show()

# %% [markdown]
# ### Data Visualization for 'Free Sulphur Dioxide'

# %%
plot1 = sns.histplot(data=dataset_2, x='free sulfur dioxide',color='#70E9FF')

plot1.set_title("Free Sulphur Dioxide Histogram") #title
# Out:
# Text(0.5, 1.0, 'Free Sulphur Dioxide Histogram')

# %%
dat_mean = dataset_2['free sulfur dioxide'].mean()

# Count values Greater than or Leass than Mean
above_mean_count = dataset_2[dataset_2['free sulfur dioxide'] > dat_mean]['free sulfur dioxide'].count()
below_mean_count = dataset_2[dataset_2['free sulfur dioxide'] < dat_mean]['free sulfur dioxide'].count()

# Create pie chart
labels = ['Greater than mean', 'Less than mean']
sizes = [above_mean_count, below_mean_count]
colors = ['yellow', 'lightblue']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Free Sulfur Dioxide Greater than or Leass than Mean')
plt.show()

# %% [markdown]
# ### Data Visualization for 'Total Sulfur Dioxide'

# %%
plot1 = sns.histplot(data=dataset_2, x='total sulfur dioxide',color='#70E9FF')

plot1.set_title("Total Sulfur Dioxide") #title
# Out:
# Text(0.5, 1.0, 'Total Sulfur Dioxide')

# %%
dat_mean = dataset_2['total sulfur dioxide'].mean()

# Count values Greater than or Leass than Mean
above_mean_count = dataset_2[dataset_2['total sulfur dioxide'] > dat_mean]['total sulfur dioxide'].count()
below_mean_count = dataset_2[dataset_2['total sulfur dioxide'] < dat_mean]['total sulfur dioxide'].count()

# Create pie chart
labels = ['Greater than mean', 'Less than mean']
sizes = [above_mean_count, below_mean_count]
colors = ['gray', 'light#70E9FF']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Total Sulfur Dioxide Greater than or Leass than Mean')
plt.show()

# %% [markdown]
# ### Data Visualization for 'Density'

# %%
plot1 = sns.histplot(data=dataset_2, x='density',color='#70E9FF')

plot1.set_title("Density Histogram") #title
# Out:
# Text(0.5, 1.0, 'Density Histogram')

# %%
dat_mean = dataset_2['density'].mean()

# Count values Greater than or Leass than Mean
above_mean_count = dataset_2[dataset_2['density'] > dat_mean]['density'].count()
below_mean_count = dataset_2[dataset_2['density'] < dat_mean]['density'].count()

# Create pie chart
labels = ['Greater than mean', 'Less than mean']
sizes = [above_mean_count, below_mean_count]
colors = ['purple', 'light#70E9FF']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Density Greater than or Leass than Mean')
plt.show()

# %% [markdown]
# ### Data Visualization for 'pH'

# %%
plot1 = sns.histplot(data=dataset_2, x='pH',,color='#70E9FF')

plot1.set_title("pH Histogram") #title
# Out:
# Text(0.5, 1.0, 'pH Histogram')

# %%
dat_mean = dataset_2['pH'].mean()

# Count values Greater than or Leass than Mean
above_mean_count = dataset_2[dataset_2['pH'] > dat_mean]['pH'].count()
below_mean_count = dataset_2[dataset_2['chlorides'] < dat_mean]['pH'].count()

# Create pie chart
labels = ['Greater than mean', 'Less than mean']
sizes = [above_mean_count, below_mean_count]
colors = ['yellow', 'lightblue']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('pH Greater than or Leass than Mean')
plt.show()

# %% [markdown]
# ### Data Visualization for 'Sulphates'

# %%
plot1 = sns.histplot(data=dataset_2, x='sulphates',,color='#70E9FF')

plot1.set_title("Sulphates Histogram") #title
# Out:
# Text(0.5, 1.0, 'Sulphates Histogram')

# %%
dat_mean = dataset_2['sulphates'].mean()

# Count values Greater than or Leass than Mean
above_mean_count = dataset_2[dataset_2['sulphates'] > dat_mean]['sulphates'].count()
below_mean_count = dataset_2[dataset_2['sulphates'] < dat_mean]['sulphates'].count()

# Create pie chart
labels = ['Greater than mean', 'Less than mean']
sizes = [above_mean_count, below_mean_count]
colors = ['pink', 'light#70E9FF']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Sulphates Greater than or Leass than Mean')
plt.show()

# %% [markdown]
# ### Data Visualization for 'Achohol'

# %%
plot1 = sns.histplot(data=dataset_2, x='alcohol',,color='#70E9FF')

plot1.set_title("Alcohol Histogram") #title
# Out:
# Text(0.5, 1.0, 'Alcohol Histogram')

# %%
dat_mean = dataset_2['alcohol'].mean()

# Count values Greater than or Leass than Mean
above_mean_count = dataset_2[dataset_2['alcohol'] > dat_mean]['alcohol'].count()
below_mean_count = dataset_2[dataset_2['alcohol'] < dat_mean]['alcohol'].count()

# Create pie chart
labels = ['Greater than mean', 'Less than mean']
sizes = [above_mean_count, below_mean_count]
colors = ['purple', 'blue']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Alcohol Greater than or Leass than Mean')
plt.show()

# %% [markdown]
# ### Data Visualization for 'Quality'

# %%
plot1 = sns.histplot(data=dataset_2, x='quality',color='#70E9FF')

plot1.set_title("Quality Histogram") #title
# Out:
# Text(0.5, 1.0, 'Quality Histogram')

# %%
dat_mean = dataset_2['quality'].mean()

# Count values Greater than or Leass than Mean
above_mean_count = dataset_2[dataset_2['quality'] > dat_mean]['quality'].count()
below_mean_count = dataset_2[dataset_2['quality'] < dat_mean]['quality'].count()

# Create pie chart
labels = ['Greater than mean', 'Less than mean']
sizes = [above_mean_count, below_mean_count]
colors = ['lavender', 'yellow'] 
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Quality Greater than or Leass than Mean')
plt.show()
